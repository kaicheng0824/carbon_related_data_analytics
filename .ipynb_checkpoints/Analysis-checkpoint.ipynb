# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
plt.style.use("seaborn")

# %%
theYear = 2018
year = pd.DataFrame()
for i in range(12):
    theMonth = i+1
    if(theMonth < 10):
        theMonth = "0"+str(theMonth)
    else:
        theMonth = str(theMonth)
    month = pd.read_csv("marginal_emission/SGIP_CAISO_SDGE/SGIP_CAISO_SDGE_{}-{}_ALL_MOER_VERSIONS.csv".format(theYear,theMonth),parse_dates=['timestamp'])
    year = pd.concat([year, month], axis=0)

# %%
year
# Out:
#                      timestamp  MOER version 2.0  MOER version 1.0
# 0    2018-01-01 00:00:00+00:00          0.288456          0.203566
# 1    2018-01-01 00:05:00+00:00          0.288998          0.203988
# 2    2018-01-01 00:10:00+00:00          0.292090          0.206398
# 3    2018-01-01 00:15:00+00:00          0.299231          0.211964
# 4    2018-01-01 00:20:00+00:00          0.302720          0.214683
# ...                        ...               ...               ...
# 8923 2018-12-31 23:35:00+00:00          0.227049          0.182122
# 8924 2018-12-31 23:40:00+00:00          0.239506          0.192848
# 8925 2018-12-31 23:45:00+00:00          0.271948          0.220783
# 8926 2018-12-31 23:50:00+00:00          0.303090          0.247599
# 8927 2018-12-31 23:55:00+00:00          0.305393          0.249582
#
# [105120 rows x 3 columns]

# %%
print(month.dtypes)
# Out:
# timestamp           datetime64[ns, UTC]
# MOER version 2.0                float64
# MOER version 1.0                float64
# dtype: object

# %%
q1 = year[6000:7000]
q1.plot(x="timestamp", y="MOER version 2.0")
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
def isLeapYr(theYear):
    if ((theYear % 4 == 0) and (theYear % 100 != 0)) or (theYear % 400 == 0):
        return 366
    else:
        return 365

# %%
# Create Heatmap
if isLeapYr(theYear)==True:
    day = 366
else:
    day = 365
time = 12*24
matrix = np.zeros(day*time,dtype=float)

MOERV2 = 1

plt.figure(figsize=(time,day))

for i in range (day):
    for j in range (time):
        MOER = year.iloc[int(i*time+j),MOERV2]
        #print(i*time+j)
        #print(MOER)
#         #print(year[i*time+j:i*time+j+1]['MOER version 2.0'].astype(float))
#         #MOER = year[i*time+j:i*time+j+1]['MOER version 2.0'].astype(float)
#         MOER = year[i*time+j:i*time+j+1]['MOER version 2.0']
#         MOER = str(MOER)[5:13]
#         print(MOER)
#         if(MOER=='0.0'):
#             MOER = 0
#         MOER = float(MOER)
        matrix[i*time+j] = MOER

# %%
matrix = matrix.reshape(day,time)
# print(matrix)

# %%
theIndex = np.zeros(time,dtype=object)
for i in range(time):
    minute = (i*5)%60
    if minute < 10:
        minute = "0"+str(minute)
    hour = int(i/12)
    if hour < 10:
        hour = "0"+str(hour)
    
    hour = str(hour)
    minute = str(minute)
    timeStr = hour+":"+minute
    theIndex[i] = timeStr
    
theColumn = np.zeros(day,dtype=object)
if isLeapYr(theYear)==True:
    month_arr = [31,29,31,30,31,30,31,31,30,31,30,31]
else:
    month_arr = [31,28,31,30,31,30,31,31,30,31,30,31]

month_idx = 1
day_elapse = 1
for i in range(day):
    if day_elapse > month_arr[month_idx-1]:
        month_idx += 1
        day_elapse = 1
        
    if month_idx < 10:
        month = "0"+(str(month_idx))
# 23:45    0.663750    0.636532    0.314080    0.298484  ...    0.257696
# 23:50    0.663750    0.663750    0.347188    0.365300  ...    0.260834
# 23:55    0.663750    0.663750    0.397688    0.388481  ...    0.270079
#
#        2018-12-23  2018-12-24  2018-12-25  2018-12-26  2018-12-27  2018-12-28  \
# 00:00    0.195445    0.204863    0.175878    0.180015    0.245107    0.293819
# 00:05    0.202958    0.173561    0.155727    0.164140    0.224565    0.262363
# 00:10    0.212827    0.183494    0.152638    0.178537    0.211803    0.220793
# 00:15    0.219440    0.208643    0.167127    0.182679    0.239125    0.266407
# 00:20    0.227843    0.211997    0.179517    0.205103    0.245596    0.268538
# ...           ...         ...         ...         ...         ...         ...
# 23:35    0.200967    0.188286    0.109363    0.288964    0.328636    0.257071
# 23:40    0.209220    0.193120    0.131638    0.297867    0.328636    0.290354
# 23:45    0.248380    0.205831    0.175943    0.337011    0.355108    0.338861
# 23:50    0.278708    0.199444    0.232967    0.330682    0.363365    0.353074
# 23:55    0.299652    0.194153    0.212514    0.335686    0.382034    0.355465
#
#        2018-12-29  2018-12-30  2018-12-31
# 00:00    0.243134    0.230526    0.154538
# 00:05    0.207758    0.189700    0.159256
# 00:10    0.217995    0.198786    0.177419
# 00:15    0.245483    0.204514    0.185699
# 00:20    0.262435    0.207649    0.188622
# ...           ...         ...         ...
# 23:35    0.191181    0.174098    0.227049
# 23:40    0.234792    0.183979    0.239506
# 23:45    0.287019    0.192121    0.271948
# 23:50    0.287019    0.192993    0.303090
# 23:55    0.287019    0.186219    0.305393
#
# [288 rows x 365 columns]

# %%
# month.plot(x="timestamp", y=["MOER version 2.0", "MOER version 1.0"])
yearplt = plt.axes()
heat_map = sns.heatmap(matrix.T)
yearplt.set_title('Year {}'.format(theYear))
plt.savefig("./plots/marginal_emission_heatmap{}.png".format(theYear))
plt.show()

# %%
# Analyze Different Season
# spring = df2[59:152].mean().iloc[1:]
# summer = df2[152:243].mean().iloc[1:]
# autumn = df2[243:334].mean().iloc[1:]
# winter = pd.concat([df2[334:365],df2[0:59]]).mean().iloc[1:]

spring = matrix.loc[:][59:152].T
summer = matrix.loc[:][152:243].T
autumn = matrix.loc[:][243:334].T
winter = pd.concat([matrix[334:365],matrix[0:59]]).T

springPlt = plt.axes()
heat_map_spring = sns.heatmap(spring)
springPlt.set_title('Spring {}'.format(theYear))
plt.savefig("./plots/marginal_emission_heatmap{}_spring.png".format(theYear))
plt.show()

# %%
summerPlt = plt.axes()
summerPlt.set_title('Summer {}'.format(theYear))
heat_map_summer = sns.heatmap(summer)
plt.savefig("./plots/marginal_emission_heatmap{}_summer.png".format(theYear))
plt.show()

# %%
fallPlt = plt.axes()
heat_map_autumn = sns.heatmap(autumn)
fallPlt.set_title('Fall {}'.format(theYear))
plt.savefig("./plots/marginal_emission_heatmap{}_fall.png".format(theYear))
plt.show()

# %%
winterPlt = plt.axes()
heat_map_winter = sns.heatmap(winter)
winterPlt.set_title('Winter {}'.format(theYear))
plt.savefig("./plots/marginal_emission_heatmap{}_winter.png".format(theYear))
plt.show()
