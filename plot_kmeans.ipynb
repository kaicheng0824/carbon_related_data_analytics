# %%
# %matplotlib inline

# %% [markdown]
# # k-means
#
# This example uses $k$-means clustering for time series. Three variants of
# the algorithm are available: standard
# Euclidean $k$-means, DBA-$k$-means (for DTW Barycenter
# Averaging [1])
# and Soft-DTW $k$-means [2].
#
# In the figure below, each row corresponds to the result of a different
# clustering. In a row, each sub-figure corresponds to a cluster.
# It represents the set
# of time series from the training set that were assigned to the considered
# cluster (in black) as well as the barycenter of the cluster (in red).
#
# ## A note on pre-processing
#
# In this example, time series are preprocessed using
# `TimeSeriesScalerMeanVariance`. This scaler is such that each output time
# series has zero mean and unit variance.
# The assumption here is that the range of a given time series is uninformative
# and one only wants to compare shapes in an amplitude-invariant manner (when
# time series are multivariate, this also rescales all modalities such that there
# will not be a single modality responsible for a large part of the variance).
# This means that one cannot scale barycenters back to data range because each
# time series is scaled independently and there is hence no such thing as an
# overall data range.
#
# [1] F. Petitjean, A. Ketterlin & P. Gancarski. A global averaging method for dynamic time warping, with applications to clustering. Pattern Recognition, Elsevier, 2011, Vol. 44, Num. 3, pp. 678-693
# [2] M. Cuturi, M. Blondel "Soft-DTW: a Differentiable Loss Function for Time-Series," ICML 2017.

# %%
# Author: Romain Tavenard
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from tslearn.clustering import TimeSeriesKMeans
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, \
    TimeSeriesResampler

seed = 0
numpy.random.seed(seed)
X_train, y_train, X_test, y_test = CachedDatasets().load_dataset("Trace")
pd_test = pd.read_csv("SDGE_2021_MOER.csv")
np_data = np.zeros((365,288),dtype=float)
for i in range(365):
    np_data[i] = pd_test.iloc[i].to_numpy()[1:]

plt.plot(np_data[364].ravel(), "k-", alpha=.2)

# %%
plt.plot(np_data[20].ravel(), "k-", alpha=.2)
# for xx in X_train:
#     plt.plot(xx.ravel(), "k-", alpha=.2)

# %%
# X_train = X_train[y_train < 4]  # Keep first 3 classes
# numpy.random.shuffle(X_train)
# # Keep only 50 time series
# X_train = TimeSeriesScalerMeanVariance().fit_transform(X_train[:50])
# # Make time series shorter
# X_train = TimeSeriesResampler(sz=40).fit_transform(X_train)
sz = X_train.shape[1]
print(sz)
# Out:
# 275

# %%
clusters = 15
# Euclidean k-means
print("Euclidean k-means")
km = TimeSeriesKMeans(n_clusters=clusters, verbose=True, random_state=seed)
y_pred = km.fit_predict(np_data)

# print(y_pred)
plt.hist(y_pred, bins='auto')

for yi in range(clusters):
    plt.figure(yi)
#     plt.subplot(3, 3, yi + 1)
    for xx in np_data[y_pred == yi]:
        plt.plot(xx.ravel(), "k-", alpha=.2)
#     print(km.cluster_centers_[yi])
    plt.plot(km.cluster_centers_[yi].ravel(), "r-")
    plt.xlim(0, sz)
    plt.ylim(0, 0.8)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)
#     plt.text
    if yi == 1:
        plt.title("Euclidean $k$-means")
    plt.show()
# Out:
# Euclidean k-means
# 2.554 --> 1.820 --> 1.751 --> 1.717 --> 1.698 --> 1.691 --> 1.687 --> 1.684 --> 1.682 --> 1.681 --> 1.680 --> 1.680 --> 1.680 -->

# %%
# DBA-k-means
DBA_cluster = 2
print("DBA k-means")
dba_km = TimeSeriesKMeans(n_clusters=DBA_cluster,
                          n_init=2,
                          metric="dtw",
                          verbose=True,
                          max_iter_barycenter=10,
                          random_state=seed)
y_pred = dba_km.fit_predict(np_data)
# Out:
# DBA k-means
# Init 1
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 365 out of 365 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 730 out of 730 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 730 out of 730 | elapsed:    0.4s finished
# 1.721 -->
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 730 out of 730 | elapsed:    0.4s finished
# 0.563 -->
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/1n/787vmy157kq5kpk7w7n5wwxh0000gn/T/ipykernel_58322/2673943275.py in <module>
#       8                           max_iter_barycenter=10,
#       9                           random_state=seed)
# ---> 10 y_pred = dba_km.fit_predict(np_data)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tslearn/clustering/kmeans.py in fit_predict(self, X, y)
#     811         """
#     812         X = check_array(X, allow_nd=True, force_all_finite='allow-nan')
# --> 813         return self.fit(X, y).labels_
#     814
#     815     def predict(self, X):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tslearn/clustering/kmeans.py in fit(self, X, y)
#     778                     print("Init %d" % (n_successful + 1))
#     779                 n_attempts += 1
# --> 780                 self._fit_one_init(X_, x_squared_norms, rs)
#     781                 if self.inertia_ < min_inertia:
#     782                     best_correct_centroids = self.cluster_centers_.copy()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tslearn/clustering/kmeans.py in _fit_one_init(self, X, x_squared_norms, rs)
#     663             if self.verbose:
#     664                 print("%.3f" % self.inertia_, end=" --> ")
# --> 665             self._update_centroids(X)
#     666
#     667             if numpy.abs(old_inertia - self.inertia_) < self.tol:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tslearn/clustering/kmeans.py in _update_centroids(self, X)
#     716                     init_barycenter=self.cluster_centers_[k],
#     717                     metric_params=metric_params,
# --> 718                     verbose=False)
#     719             elif self.metric == "softdtw":
#     720                 self.cluster_centers_[k] = softdtw_barycenter(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tslearn/barycenters/dba.py in dtw_barycenter_averaging(X, barycenter_size, init_barycenter, max_iter, tol, weights, metric_params, verbose, n_init)
#     504             weights=weights,
#     505             metric_params=metric_params,
# --> 506             verbose=verbose
#     507         )
#     508         if loss < best_cost:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tslearn/barycenters/dba.py in dtw_barycenter_averaging_one_init(X, barycenter_size, init_barycenter, max_iter, tol, weights, metric_params, verbose)
#     590         list_p_k, cost = _mm_assignment(X_, barycenter, weights, metric_params)
#     591         diag_sum_v_k, list_w_k = _mm_valence_warping(list_p_k, barycenter_size,
# --> 592                                                      weights)
#     593         if verbose:
#     594             print("[DBA] epoch %d, cost: %.3f" % (it + 1, cost))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tslearn/barycenters/dba.py in _mm_valence_warping(list_p_k, barycenter_size, weights)
#     304         list_p_k=list_p_k,
#     305         barycenter_size=barycenter_size,
# --> 306         weights=weights)
#     307     diag_sum_v_k = numpy.zeros(list_v_k[0].shape)
#     308     for v_k in list_v_k:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tslearn/barycenters/dba.py in _subgradient_valence_warping(list_p_k, barycenter_size, weights)
#     260         w_k = numpy.zeros((barycenter_size, sz_k))
#     261         for i, j in p_k:
# --> 262             w_k[i, j] = 1.
#     263         list_w_k.append(w_k * weights[k])
#     264         list_v_k.append(w_k.sum(axis=1) * weights[k])
#
# KeyboardInterrupt:

# %%
for yi in range(DBA_cluster):
    plt.subplot(3, 3, 4 + yi)
    for xx in np_data[y_pred == yi]:
        plt.plot(xx.ravel(), "k-", alpha=.2)
    plt.plot(dba_km.cluster_centers_[yi].ravel(), "r-")
    plt.xlim(0, sz)
    plt.ylim(0, 1)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)
    if yi == 1:
        plt.title("DBA $k$-means")

# %%
# Soft-DTW-k-means
print("Soft-DTW k-means")
sdtw_km = TimeSeriesKMeans(n_clusters=3,
                           metric="softdtw",
                           metric_params={"gamma": .01},
                           verbose=True,
                           random_state=seed)
y_pred = sdtw_km.fit_predict(X_train)

for yi in range(3):
    plt.subplot(3, 3, 7 + yi)
    for xx in X_train[y_pred == yi]:
        plt.plot(xx.ravel(), "k-", alpha=.2)
    plt.plot(sdtw_km.cluster_centers_[yi].ravel(), "r-")
    plt.xlim(0, sz)
    plt.ylim(-4, 4)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)
    if yi == 1:
        plt.title("Soft-DTW $k$-means")

plt.tight_layout()
plt.show()
