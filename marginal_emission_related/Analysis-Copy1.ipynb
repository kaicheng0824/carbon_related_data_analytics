# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
plt.style.use("seaborn")

# %%
#CAISO_2021_Daily_CO2_Intensity.csv
theYear = 2021
#PGE SCE SDGE
region="California Average CO2"
year = pd.DataFrame()
# for i in range(12):
#     theMonth = i+1
#     if(theMonth < 10):
#         theMonth = "0"+str(theMonth)
#     else:
#         theMonth = str(theMonth)
avgCO2 = pd.read_csv("processed_data/AverageCO2/CAISO_2021_Daily_CO2_Intensity.csv",parse_dates=[0])
# year = pd.concat([year, month], axis=0)
avgCO2
# Out:
#      01/01/2021     00:00     00:05     00:10     00:15     00:20     00:25  \
# 0    2021-01-01  0.335901  0.334830  0.334084  0.333514  0.332926  0.332363
# 1    2021-01-02  0.355356  0.357970  0.359634  0.360489  0.361371  0.361624
# 2    2021-01-03  0.335651  0.337043  0.336985  0.337727  0.337332  0.338844
# 3    2021-01-04  0.353613  0.353941  0.357412  0.356541  0.356814  0.356509
# 4    2021-01-05  0.333408  0.336061  0.335893  0.333995  0.332822  0.333741
# ..          ...       ...       ...       ...       ...       ...       ...
# 360  2021-12-27  0.275707  0.284114  0.283742  0.283113  0.282802  0.282740
# 361  2021-12-28  0.295316  0.293845  0.298420  0.301998  0.301135  0.296924
# 362  2021-12-29  0.305861  0.308656  0.307305  0.305666  0.305604  0.306813
# 363  2021-12-30  0.323806  0.327640  0.326704  0.323517  0.322127  0.320276
# 364  2021-12-31  0.317723  0.317066  0.315614  0.314385  0.313225  0.312936
#
#         00:30     00:35     00:40  ...     23:10     23:15     23:20  \
# 0    0.332617  0.332568  0.331631  ...  0.362058  0.361317  0.360568
# 1    0.361270  0.361776  0.361633  ...  0.319420  0.320125  0.319964
# 2    0.339826  0.341933  0.341665  ...  0.352158  0.352987  0.354157
# 3    0.355502  0.353821  0.353447  ...  0.327001  0.326965  0.326381
# 4    0.332879  0.334246  0.332723  ...  0.354828  0.352390  0.352615
# ..        ...       ...       ...  ...       ...       ...       ...
# 360  0.284342  0.282463  0.289516  ...  0.295640  0.293581  0.292626
# 361  0.295968  0.295842  0.294020  ...  0.297426  0.298865  0.299251
# 362  0.307309  0.307457  0.306574  ...  0.323041  0.320747  0.321460
# 363  0.318901  0.319745  0.318469  ...  0.317040  0.316167  0.316157
# 364  0.313598  0.313856  0.314209  ...  0.288332  0.287207  0.289867
#
#         23:25     23:30     23:35     23:40     23:45     23:50  23:55
# 0    0.358481  0.357823  0.357190  0.356413  0.356456  0.356491    NaN
# 1    0.320832  0.322551  0.325286  0.327844  0.329061  0.333769    NaN
# 2    0.353235  0.352302  0.351704  0.352047  0.351972  0.354215    NaN
# 3    0.326959  0.327356  0.328152  0.332673  0.334411  0.334386    NaN
# 4    0.353012  0.354088  0.353746  0.355427  0.355327  0.356500    NaN
# ..        ...       ...       ...       ...       ...       ...    ...
# 360  0.293272  0.295437  0.296646  0.297960  0.297077  0.296178    NaN
# 361  0.297904  0.298146  0.299611  0.300205  0.302125  0.302776    NaN
# 362  0.321657  0.322625  0.322311  0.322473  0.323252  0.324167    NaN
    if ((theYear % 4 == 0) and (theYear % 100 != 0)) or (theYear % 400 == 0):
        return 366
    else:
        return 365

# %%
# Create Heatmap
if isLeapYr(theYear)==True:
    day = 366
else:
    day = 365
time = 12*24
# matrix = np.zeros(day*time,dtype=float)

# MOERV2 = 1

plt.figure(figsize=(time,day))

# for i in range (day):
#     for j in range (time):
#         matrix[i*time+j] = year.iloc[int(i*time+j),time]

# %%
# matrix = matrix.reshape(day,time)
# # print(matrix)

# %%
theIndex = np.zeros(time,dtype=object)
for i in range(time):
    minute = (i*5)%60
    if minute < 10:
        minute = "0"+str(minute)
    hour = int(i/12)
    if hour < 10:
        hour = "0"+str(hour)
    
    hour = str(hour)
    minute = str(minute)
    timeStr = hour+":"+minute
    theIndex[i] = timeStr
    
theColumn = np.zeros(day,dtype=object)
if isLeapYr(theYear)==True:
    month_arr = [31,29,31,30,31,30,31,31,30,31,30,31]
else:
    month_arr = [31,28,31,30,31,30,31,31,30,31,30,31]

month_idx = 1
day_elapse = 1
for i in range(day):
    if day_elapse > month_arr[month_idx-1]:
        month_idx += 1
        day_elapse = 1
        
    if month_idx < 10:
        month = "0"+(str(month_idx))
    else:
        month = str(month_idx)
    
    if day_elapse < 10:
        day_idx = "0"+(str(day_elapse))
    else:
        day_idx = str(day_elapse)
        
    theColumn[i] = (str(theYear)) +"-"+ month +"-"+ day_idx
    day_elapse += 1

theColumn = theColumn.tolist()
theIndex = theIndex.tolist()
# print(theIndex)
# print(theColumn)
avgCO2
# Out:
#         00:00     00:05     00:10     00:15     00:20     00:25     00:30  \
# 0    0.335901  0.334830  0.334084  0.333514  0.332926  0.332363  0.332617
# 1    0.355356  0.357970  0.359634  0.360489  0.361371  0.361624  0.361270
# 2    0.335651  0.337043  0.336985  0.337727  0.337332  0.338844  0.339826
# 3    0.353613  0.353941  0.357412  0.356541  0.356814  0.356509  0.355502
# 4    0.333408  0.336061  0.335893  0.333995  0.332822  0.333741  0.332879
# ..        ...       ...       ...       ...       ...       ...       ...
# 360  0.275707  0.284114  0.283742  0.283113  0.282802  0.282740  0.284342
# 361  0.295316  0.293845  0.298420  0.301998  0.301135  0.296924  0.295968
# 362  0.305861  0.308656  0.307305  0.305666  0.305604  0.306813  0.307309
# 363  0.323806  0.327640  0.326704  0.323517  0.322127  0.320276  0.318901
# 364  0.317723  0.317066  0.315614  0.314385  0.313225  0.312936  0.313598
#
#         00:35     00:40     00:45  ...     23:10     23:15     23:20  \
# 0    0.332568  0.331631  0.330993  ...  0.362058  0.361317  0.360568
# 1    0.361776  0.361633  0.361476  ...  0.319420  0.320125  0.319964
# 2    0.341933  0.341665  0.341501  ...  0.352158  0.352987  0.354157
# 3    0.353821  0.353447  0.354041  ...  0.327001  0.326965  0.326381
# 4    0.334246  0.332723  0.332705  ...  0.354828  0.352390  0.352615
# ..        ...       ...       ...  ...       ...       ...       ...
# 360  0.282463  0.289516  0.290463  ...  0.295640  0.293581  0.292626
# 361  0.295842  0.294020  0.295383  ...  0.297426  0.298865  0.299251
# 362  0.307457  0.306574  0.306121  ...  0.323041  0.320747  0.321460
# 363  0.319745  0.318469  0.318205  ...  0.317040  0.316167  0.316157
# 364  0.313856  0.314209  0.315143  ...  0.288332  0.287207  0.289867
#
#         23:25     23:30     23:35     23:40     23:45     23:50  23:55
# 0    0.358481  0.357823  0.357190  0.356413  0.356456  0.356491    NaN
# 1    0.320832  0.322551  0.325286  0.327844  0.329061  0.333769    NaN
# 2    0.353235  0.352302  0.351704  0.352047  0.351972  0.354215    NaN
# 3    0.326959  0.327356  0.328152  0.332673  0.334411  0.334386    NaN
# 4    0.353012  0.354088  0.353746  0.355427  0.355327  0.356500    NaN
# ..        ...       ...       ...       ...       ...       ...    ...
# 360  0.293272  0.295437  0.296646  0.297960  0.297077  0.296178    NaN
# 361  0.297904  0.298146  0.299611  0.300205  0.302125  0.302776    NaN
# 362  0.321657  0.322625  0.322311  0.322473  0.323252  0.324167    NaN
# 363  0.314628  0.314821  0.314838  0.314224  0.315349  0.317317    NaN
# 364  0.287624  0.287056  0.287693  0.288745  0.290062  0.290922    NaN
#
# [365 rows x 288 columns]

# %%
avgCO2.columns = theIndex
avgCO2.index = theColumn
# matrix = pd.DataFrame(avgCO2, columns=theIndex,index=theColumn)
# matrix.T
# matrix.to_csv('./processed_data/{}_{}_MOER.csv'.format(region,theYear),index=True)

# %%
# month.plot(x="timestamp", y=["MOER version 2.0", "MOER version 1.0"])
yearplt = plt.axes()
heat_map = sns.heatmap(avgCO2.T)
yearplt.set_title('{}: Year {}'.format(region,theYear))
plt.savefig("./plots/heatmap/AVGCO2_{}.png".format(theYear))
plt.show()

# %%
# Analyze Different Season
# spring = df2[59:152].mean().iloc[1:]
# summer = df2[152:243].mean().iloc[1:]
# autumn = df2[243:334].mean().iloc[1:]
# winter = pd.concat([df2[334:365],df2[0:59]]).mean().iloc[1:]

spring = matrix.loc[:][59:152].T
summer = matrix.loc[:][152:243].T
autumn = matrix.loc[:][243:334].T
winter = pd.concat([matrix[334:365],matrix[0:59]]).T

springPlt = plt.axes()
heat_map_spring = sns.heatmap(spring)
springPlt.set_title('{}: Spring {}'.format(region,theYear))
plt.savefig("./plots/heatmap/{}/MOER_heatmap_{}_{}_spring.png".format(region,region,theYear))
plt.show()

# %%
summerPlt = plt.axes()
summerPlt.set_title('{}: Summer {}'.format(region,theYear))
heat_map_summer = sns.heatmap(summer)
plt.savefig("./plots/heatmap/{}/MOER_heatmap_{}_{}_summer.png".format(region,region,theYear))
plt.show()

# %%
fallPlt = plt.axes()
heat_map_autumn = sns.heatmap(autumn)
fallPlt.set_title('{}: Fall {}'.format(region,theYear))
plt.savefig("./plots/heatmap/{}/MOER_heatmap_{}_{}_fall.png".format(region,region,theYear))
plt.show()

# %%
winterPlt = plt.axes()
heat_map_winter = sns.heatmap(winter)
winterPlt.set_title('{}: Winter {}'.format(region,theYear))
plt.savefig("./plots/heatmap/{}/MOER_heatmap_{}_{}_winter.png".format(region,region,theYear))
plt.show()
