# %%
import pandas as pd
import numpy as np

# %%
tac = pd.read_csv('./data/TAC_to_PNODE.csv')
sdge_pnode = pd.read_csv('./data/Node_Data/CAISO_SDGE_Node.csv')
all_gen_pnode = pd.read_csv('./powerplant_location.csv')

# %%
tac
# Out:
#      TAC_AREA_ID                   PNODE_ID DESCRIPTION  COMMENTS  \
# 0      TAC_NORTH            OAKLND12_7_N101   TAC_NORTH       NaN
# 1      TAC_NORTH                PIT6U2_7_B1   TAC_NORTH       NaN
# 2      TAC_NORTH            CAPTJACK_5_N015   TAC_NORTH       NaN
# 3      TAC_NORTH               Q481_7_GN001   TAC_NORTH       NaN
# 4       TAC_BANC               ELK_GNODEESC    TAC_BANC       NaN
# ...          ...                        ...         ...       ...
# 3866    TAC_BPAT  HRW_1_HOPKRIDG_PLANT-APND    TAC_BPAT       NaN
# 3867   TAC_ECNTR         SCNW_6_PDRP66-APND   TAC_ECNTR       NaN
# 3868   TAC_ECNTR        SCEC_1_PDRP187-APND   TAC_ECNTR       NaN
# 3869   TAC_NORTH        PGF1_2_PDRP108-APND   TAC_NORTH       NaN
# 3870    TAC_BPAT     UPRCOL_5_BASE_ORA-APND    TAC_BPAT       NaN
#
#              EFF_START_DT           EFF_END_DT           EFF_START_DT_GMT  \
# 0     2021-01-01T00:00:00  2030-12-31T23:59:59  2021-01-01T08:00:00-00:00
# 1     2022-05-26T00:00:00  2030-12-31T23:59:59  2022-05-26T07:00:00-00:00
# 2     2022-01-01T00:00:00  2030-12-31T23:59:59  2022-01-01T08:00:00-00:00
# 3     2017-11-01T00:00:00  2030-12-31T23:59:59  2017-11-01T07:00:00-00:00
# 4     2022-01-01T00:00:00  2030-12-31T23:59:59  2022-01-01T08:00:00-00:00
# ...                   ...                  ...                        ...
# 3866  2022-05-03T00:00:00  2030-12-31T23:59:59  2022-05-03T07:00:00-00:00
# 3867  2022-07-01T00:00:00  2030-12-31T23:59:59  2022-07-01T07:00:00-00:00
# 3868  2022-07-01T00:00:00  2030-12-31T23:59:59  2022-07-01T07:00:00-00:00
# 3869  2022-07-11T00:00:00  2030-12-31T23:59:59  2022-07-11T07:00:00-00:00
# 3870  2022-05-03T00:00:00  2030-12-31T23:59:59  2022-05-03T07:00:00-00:00
#
#                  EFF_END_DT_GMT
# 0     2031-01-01T07:59:59-00:00
# 1     2031-01-01T07:59:59-00:00
# 2     2031-01-01T07:59:59-00:00
# 3     2031-01-01T07:59:59-00:00
# 4     2031-01-01T07:59:59-00:00
# ...                         ...
# 3866  2031-01-01T07:59:59-00:00
# 3867  2031-01-01T07:59:59-00:00
# 3868  2031-01-01T07:59:59-00:00
# 3869  2031-01-01T07:59:59-00:00
# 3870  2031-01-01T07:59:59-00:00
#
# [3871 rows x 8 columns]

# %%
sdge_pnode
# Out:
#        AS_ID RES_TYPE          RES_ID         PNODE_ID  \
# 0    AS_SP26      GEN   SYDRO_6_FCELL  SANYSDRO_6_N013
# 1    AS_SP15      GEN   SYDRO_6_FCELL  SANYSDRO_6_N013
# 2    AS_SP15     LOAD    SYDRO_6_LD32  SANYSDRO_6_N004
# 3    AS_SP26     LOAD    SYDRO_6_LD32  SANYSDRO_6_N004
# 4    AS_SP26     LOAD    SYDRO_6_LD31  SANYSDRO_6_N001
# ..       ...      ...             ...              ...
# 511  AS_SP26     LOAD   SNTABL_6_LD30  SANTYSBL_6_N001
# 512  AS_SP26     LOAD    WRNERS_6_LD1   WARNERS_6_N001
# 513  AS_SP15     LOAD    WRNERS_6_LD1   WARNERS_6_N001
# 514  AS_SP26      GEN  BREGGO_6_SOLAR   BORREGO_6_N009
# 515  AS_SP15      GEN  BREGGO_6_SOLAR   BORREGO_6_N009
#
#                        BUS_ID  FNMVERSION        RELEASE_DATE  GROUP  \
# 0    22740_SANYSDRO_69.0_GUM1  22M7_DB114  2022-07-28 0:00:00   4836
# 1    22740_SANYSDRO_69.0_GUM1  22M7_DB114  2022-07-28 0:00:00   4836
# 2    22740_SANYSDRO_69.0_LD32  22M7_DB114  2022-07-28 0:00:00   4838
# 3    22740_SANYSDRO_69.0_LD32  22M7_DB114  2022-07-28 0:00:00   4838
# 4    22740_SANYSDRO_69.0_LD31  22M7_DB114  2022-07-28 0:00:00   4837
# ..                        ...         ...                 ...    ...
# 511   22736_SANTYSBL_69.0_LD1  22M7_DB114  2022-07-28 0:00:00   4655
# 512   22884_WARNERS _69.0_LD1  22M7_DB114  2022-07-28 0:00:00   5340
# 513   22884_WARNERS _69.0_LD1  22M7_DB114  2022-07-28 0:00:00   5340
# 514   22084_BORREGO _69.0_GU1  22M7_DB114  2022-07-28 0:00:00    397
# 515   22084_BORREGO _69.0_GU1  22M7_DB114  2022-07-28 0:00:00    397
#
#            Lat        Long Unnamed: 10
# 0    32.545077 -117.069661         NaN
# 1    32.545077 -117.069661         NaN
# 2    32.562128 -117.026591         NaN
# 3    32.562128 -117.026591         NaN
# 4    32.562157 -117.026397         NaN
# ..         ...         ...         ...
# 511  33.110721 -116.671113         NaN
# 512  33.247363 -116.675766         NaN
# 513  33.247363 -116.675766         NaN
# 514  33.291239 -116.353036         NaN
# 515  33.291239 -116.353036         NaN
#
# [516 rows x 11 columns]

# %%
all_gen_pnode
# Out:
#       Unnamed: 0    AS_ID RES_TYPE           RES_ID        PNODE_ID  \
# 0              0  AS_SP15      GEN  7STDRD_1_SOLAR1   0096WD_7_N001
# 1              1  AS_NP26      GEN  7STDRD_1_SOLAR1   0096WD_7_N001
# 2              2  AS_SP26      GEN   ACACIA_6_SOLAR   ACACIA_7_N001
# 3              3  AS_SP15      GEN   ACACIA_6_SOLAR   ACACIA_7_N001
# 4              4  AS_NP26      GEN   ADERA_1_SOLAR1  ADERAG1_7_N001
# ...          ...      ...      ...              ...             ...
# 1697        1697  AS_NP26      GEN  WOLFSK_1_UNITA1   WOLFSKIL_7_B1
# 1698        1698  AS_NP26      GEN   WOODWR_1_HYDRO  WDWRGEN_7_N002
# 1699        1699  AS_NP15      GEN   WOODWR_1_HYDRO  WDWRGEN_7_N002
# 1700        1700  AS_NP15      GEN  WRGHTP_7_AMENGY  WRGHTPP_6_N002
# 1701        1701  AS_NP26      GEN  WRGHTP_7_AMENGY  WRGHTPP_6_N002
#
#                         BUS_ID  FNMVERSION         RELEASE_DATE  GROUP  \
# 0     35009_0096_WD _21.6_GUWD  22M7_DB114  2022-07-28T00:00:00      1
# 1     35009_0096_WD _21.6_GUWD  22M7_DB114  2022-07-28T00:00:00      1
# 2      29876_ACACIA  _34.5_GU1  22M7_DB114  2022-07-28T00:00:00      5
# 3      29876_ACACIA  _34.5_GU1  22M7_DB114  2022-07-28T00:00:00      5
# 4      34117_ADERA G1_34.5_GU1  22M7_DB114  2022-07-28T00:00:00      7
# ...                        ...         ...                  ...    ...
# 1697   32185_WOLFSKIL_13.8_GU1  22M7_DB114  2022-07-28T00:00:00   5325
# 1698  34449_WDWR GEN_21.6_GUH1  22M7_DB114  2022-07-28T00:00:00   5329
# 1699  34449_WDWR GEN_21.6_GUH1  22M7_DB114  2022-07-28T00:00:00   5329
# 1700  34272_WRGHT PP_70.0_GUM1  22M7_DB114  2022-07-28T00:00:00   5336
# 1701  34272_WRGHT PP_70.0_GUM1  22M7_DB114  2022-07-28T00:00:00   5336
#
#      CEC Plant ID Energy_Source         Lng        Lat
# 0           S0330           SUN -119.126866  35.450479
# 1           S0330           SUN -119.126866  35.450479
# 2           S0318           SUN -118.327813  34.693482
# 3           S0318           SUN -118.327813  34.693482
# 4           S0421           SUN -120.323967  37.121042
# ...           ...           ...         ...        ...
# 1697        G0913            NG -122.075155  38.228095
# 1698        H0626           WAT -119.707090  37.002469
# 1699        H0626           WAT -119.707090  37.002469
# 1700        H0455           NaN -120.932657  35.555158
# 1701        H0455           NaN -120.932657  35.555158
#
# [1702 rows x 13 columns]

# %%
joined_sdge = sdge_pnode[sdge_pnode['RES_TYPE']=='GEN'].join(tac.set_index('PNODE_ID'), on='PNODE_ID')
joined_gen = all_gen_pnode.join(tac.set_index('PNODE_ID'), on='PNODE_ID')

# %%
joined_sdge[joined_sdge['TAC_AREA_ID']=='TAC_SOUTH']
# Out:
#        AS_ID RES_TYPE           RES_ID         PNODE_ID  \
# 0    AS_SP26      GEN    SYDRO_6_FCELL  SANYSDRO_6_N013
# 1    AS_SP15      GEN    SYDRO_6_FCELL  SANYSDRO_6_N013
# 6    AS_SP15      GEN  BORDER_6_UNITA1    CPBORDER_7_B1
# 7    AS_SP26      GEN  BORDER_6_UNITA1    CPBORDER_7_B1
# 12   AS_SP26      GEN  LARKSP_6_UNIT 2    BDLRKSP2_7_B1
# ..       ...      ...              ...              ...
# 493  AS_SP26      GEN   SONGS_7_UNIT 3     SONOFR3_7_B1
# 502  AS_SP15      GEN  CRSTWD_6_KUMYAY  KUMEYAAY_7_N001
# 503  AS_SP26      GEN  CRSTWD_6_KUMYAY  KUMEYAAY_7_N001
# 514  AS_SP26      GEN   BREGGO_6_SOLAR   BORREGO_6_N009
# 515  AS_SP15      GEN   BREGGO_6_SOLAR   BORREGO_6_N009
#
#                        BUS_ID  FNMVERSION        RELEASE_DATE  GROUP  \
# 0    22740_SANYSDRO_69.0_GUM1  22M7_DB114  2022-07-28 0:00:00   4836
# 1    22740_SANYSDRO_69.0_GUM1  22M7_DB114  2022-07-28 0:00:00   4836
# 6     22149_CPBORDER_13.8_GU1  22M7_DB114  2022-07-28 0:00:00    371
# 7     22149_CPBORDER_13.8_GU1  22M7_DB114  2022-07-28 0:00:00    371
# 12    22075_BDLRKSP2_13.8_GU2  22M7_DB114  2022-07-28 0:00:00   2043
# ..                        ...         ...                 ...    ...
# 493   24130_S.ONOFR3_22.0_GU3  22M7_DB114  2022-07-28 0:00:00   4671
# 502  22904_KUMEYAAY_34.5_GUKY  22M7_DB114  2022-07-28 0:00:00    863
# 503  22904_KUMEYAAY_34.5_GUKY  22M7_DB114  2022-07-28 0:00:00    863
# 514   22084_BORREGO _69.0_GU1  22M7_DB114  2022-07-28 0:00:00    397
# 515   22084_BORREGO _69.0_GU1  22M7_DB114  2022-07-28 0:00:00    397
#
#            Lat        Long Unnamed: 10 TAC_AREA_ID DESCRIPTION  COMMENTS  \
# 0    32.545077 -117.069661         NaN   TAC_SOUTH   TAC_SOUTH       NaN
# 1    32.545077 -117.069661         NaN   TAC_SOUTH   TAC_SOUTH       NaN
# 6    32.566132 -116.944759         NaN   TAC_SOUTH   TAC_SOUTH       NaN
# 7    32.566132 -116.944759         NaN   TAC_SOUTH   TAC_SOUTH       NaN
# 12   32.567450 -116.942317         NaN   TAC_SOUTH   TAC_SOUTH       NaN
# ..         ...         ...         ...         ...         ...       ...
# 493  33.369248 -117.553319         NaN   TAC_SOUTH   TAC_SOUTH       NaN
# 502  32.699015 -116.353949         NaN   TAC_SOUTH   TAC_SOUTH       NaN
# 503  32.699015 -116.353949         NaN   TAC_SOUTH   TAC_SOUTH       NaN
# 514  33.291239 -116.353036         NaN   TAC_SOUTH   TAC_SOUTH       NaN
# 515  33.291239 -116.353036         NaN   TAC_SOUTH   TAC_SOUTH       NaN
#
#             EFF_START_DT           EFF_END_DT           EFF_START_DT_GMT  \
# 0    2017-11-01T00:00:00  2030-12-31T23:59:59  2017-11-01T07:00:00-00:00
# 1    2017-11-01T00:00:00  2030-12-31T23:59:59  2017-11-01T07:00:00-00:00
# 6    2022-01-01T00:00:00  2030-12-31T23:59:59  2022-01-01T08:00:00-00:00
# 7    2022-01-01T00:00:00  2030-12-31T23:59:59  2022-01-01T08:00:00-00:00
# 12   2022-07-20T00:00:00  2030-12-31T23:59:59  2022-07-20T07:00:00-00:00
# ..                   ...                  ...                        ...
# 493  2017-11-01T00:00:00  2030-12-31T23:59:59  2017-11-01T07:00:00-00:00
# 502  2022-01-01T00:00:00  2030-12-31T23:59:59  2022-01-01T08:00:00-00:00
# 503  2022-01-01T00:00:00  2030-12-31T23:59:59  2022-01-01T08:00:00-00:00
# 514  2022-02-09T00:00:00  2030-12-31T23:59:59  2022-02-09T08:00:00-00:00
# 515  2022-02-09T00:00:00  2030-12-31T23:59:59  2022-02-09T08:00:00-00:00
#
#                 EFF_END_DT_GMT
# 0    2031-01-01T07:59:59-00:00
# 1    2031-01-01T07:59:59-00:00
# 6    2031-01-01T07:59:59-00:00
# 7    2031-01-01T07:59:59-00:00
# 12   2031-01-01T07:59:59-00:00
# ..                         ...
# 493  2031-01-01T07:59:59-00:00
# 502  2031-01-01T07:59:59-00:00
# 503  2031-01-01T07:59:59-00:00
# 514  2031-01-01T07:59:59-00:00
# 515  2031-01-01T07:59:59-00:00
#
# [64 rows x 18 columns]

# %%
joined_sdge.to_csv('./data/Gen_Node_Data/sdge_gen_node_with_tac.csv')

# %%
joined_gen.to_csv('./data/Gen_Node_Data/all_gen_node_with_tac.csv')
