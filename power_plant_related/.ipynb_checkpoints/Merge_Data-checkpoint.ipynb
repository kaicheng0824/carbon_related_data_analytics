# %%
import pandas as pd
import numpy as np

# %%
CEC = pd.read_csv('./data/Energy_Commission_Power_Plant_ID_Cross_Reference_Table_2021_ADA.csv')
PowerPlant = pd.read_csv('./data/California_Power_Plants.csv')
Node = pd.read_csv('./data/ATL_FNM_MAPPING_DATA_GRP_CISO_AS_22M7_DB114_v5.csv')

# %%
CEC
# Out:
#      CECPlantID                       PlantName  EIAPlantID       ResourceID  \
# 0         B0001      Vaca Dixon Battery Storage     59256.0     VACADX_1_NAS
# 1         B0002       Tehachapi Storage Project     59661.0  MONLTH_6_BATTRY
# 2         B0003             Yerba Buena Battery     59257.0      SWIFT_1_NAS
# 3         B0004            Millikan Avenue BESS     60760.0  SANTGO_2_MABBT1
# 4         B0005                Mira Loma BESS A     60661.0  MIRLOM_2_MLBBTA
# ...         ...                             ...         ...              ...
# 1864      W0479    Coachella Wind Holdings, LLC     64323.0   ALTWD_2_COAWD1
# 1865      W0480                 Oasis Alta, LLC     63941.0  VOYAGR_2_VOAWD5
# 1866      W0481                      Point Wind     63482.0  TEHAPI_2_PW1WD1
# 1867      W0482              Altamont Winds LLC     64326.0              NaN
# 1868      W9999  CAISO In-State Wind Generation         NaN              NaN
#
#                Resource ID Name Energy Source Category                City  \
# 0                           NaN                BATTERY           Vacaville
# 1     Tehachapi Storage Project                BATTERY           Tehachapi
# 2                           NaN                BATTERY            San Jose
# 3          Millikan Avenue BESS                BATTERY              Irvine
# 4              Mira Loma BESS A                BATTERY             Ontario
# ...                         ...                    ...                 ...
# 1864                Coachella 1                   WIND  Desert Hot Springs
# 1865    Voyager Wind Oasis Alta                   WIND              Mojave
# 1866               Point Wind 1                   WIND           Tehachapi
# 1867                        NaN                   WIND           Livermore
# 1868                        NaN                   WIND          Sacramento
#
#               County State
# 0             Solano    CA
# 1               Kern    CA
# 2        Santa Clara    CA
# 3             Orange    CA
# 4     San Bernardino    CA
# ...              ...   ...
# 1864       Riverside    CA
# 1865            Kern    CA
# 1866            Kern    CA
# 1867         Alameda    CA
# 1868             ALL    CA
#
# [1869 rows x 9 columns]

# %%
PowerPlant
# Out:
#                  X             Y  OBJECTID_1 CECPlantID  \
# 0    -1.338598e+07  4.454253e+06        1873      G0896
# 1    -1.361147e+07  4.919580e+06        1874      S9312
# 2    -1.360463e+07  4.887791e+06        1875      G0897
# 3    -1.360025e+07  4.858596e+06        1876      S9313
# 4    -1.318512e+07  4.072714e+06        1877      G0899
# ...            ...           ...         ...        ...
# 1867 -1.334979e+07  4.326713e+06        3740      S0721
# 1868 -1.283870e+07  3.978829e+06        3741      S0722
# 1869 -1.283870e+07  3.978829e+06        3742      S0723
# 1870 -1.335358e+07  4.325432e+06        3743      S0724
# 1871 -1.306598e+07  4.113812e+06        3744      S0725
#
#                                    PlantName EIAPlantID  RPS_Eligible  \
# 0                       Chowchilla II Peaker      56185             0
# 1       Pristine Sun Fund 5 LLC_(2021_Doran)    MISSING             1
# 2                                  Red Bluff      56184             0
# 3     Pristine Sun Fund 5 LLC_(2040_Alvares)    MISSING             1
# 4                  Olive View Medical Center      10884             0
# ...                                      ...        ...           ...
# 1867                     Aquamarine Westside      62547             1
# 1868                   Maverick Solar 6, LLC      64105             1
# 1869                   Maverick Solar 7, LLC      64106             1
# 1870                              RE Slate 1      62780             1
# 1871                       High Desert Solar      64624             1
#
#       SmallPlant  Peaker  Small_Hydro  ...  State      Zip  Capacity_Latest  \
# 0              0       1            0  ...     CA  93610.0             0.00
# 1              1       0            0  ...     CA      NaN             1.50
# 2              0       1            0  ...     CA  96080.0             0.00
# 3              1       0            0  ...     CA      NaN             1.50
# 4              1       0            0  ...     CA  91342.0             5.78
# ...          ...     ...          ...  ...    ...      ...              ...
# 1867           0       0            0  ...     CA  93266.0           250.00
# 1868           0       0            0  ...     CA  92239.0           100.00
# 1869           0       0            0  ...     CA  92239.0           132.00
# 1870           0       0            0  ...     CA  93266.0           300.00
# 1871           0       0            0  ...     CA  92394.0           100.00
#
#                Units  PriEnergySource  LastReportedYear   Lon_WGS84  \
# 0                NaN              NaN            2021.0 -120.248340
# 1             Unit 1              SUN            2021.0 -122.273911
# 2                NaN              NaN            2021.0 -122.212471
# 3             Unit 1              SUN            2021.0 -122.173114
# 4     GTU #1, GTU #2               NG            2021.0 -118.443953
# ...              ...              ...               ...         ...
# 1867          W12082              SUN            2021.0 -119.923236
# 1868          Unit 1              SUN            2021.0 -115.332020
# 1869          Unit 1              NaN            2021.0 -115.332020
# 1870          Unit 1              SUN            2021.0 -119.957268
# 1871          Unit 1              SUN            2021.0 -117.373679
#
#       Lat_WGS84                                   Annual_Hyperlink  \
# 0     37.108582  https://repository.energy.ca.gov/powerplantsge...
# 1     40.368108  https://repository.energy.ca.gov/powerplantsge...
# 2     40.150187  https://repository.energy.ca.gov/powerplantsge...
# 3     39.949427  https://repository.energy.ca.gov/powerplantsge...
# 4     34.326398  https://repository.energy.ca.gov/powerplantsge...
# ...         ...                                                ...
# 1867  36.189391                                                NaN
# 1868  33.627018                                                NaN
# 1869  33.627018                                                NaN
# 1870  36.180109                                                NaN
# 1871  34.630738                                                NaN
#
#                                       Monthly_Hyperlink
# 0     https://repository.energy.ca.gov/powerplantsge...
# 1     https://caenergy.maps.arcgis.com/sharing/rest/...
# 2     https://repository.energy.ca.gov/powerplantsge...
# 3     https://caenergy.maps.arcgis.com/sharing/rest/...
# 4     https://caenergy.maps.arcgis.com/sharing/rest/...
# ...                                                 ...
# 1867                                                NaN
# 1868                                                NaN
# 1869                                                NaN
# 1870                                                NaN
# 1871                                                NaN
#
# [1872 rows x 37 columns]

# %%
Node
# Out:
#              AS_ID RES_TYPE           RES_ID        PNODE_ID  \
# 0          AS_SP15      GEN  7STDRD_1_SOLAR1   0096WD_7_N001
# 1          AS_NP26      GEN  7STDRD_1_SOLAR1   0096WD_7_N001
# 2          AS_SP15     LOAD     7STDRD_7_LD1   0096WD_7_N002
# 3          AS_NP26     LOAD     7STDRD_7_LD1   0096WD_7_N002
# 4      AS_SP26_EXP      TIE          83MB230  MIDWYGN_7_N002
# ...            ...      ...              ...             ...
# 10775      AS_NP26     LOAD     ZENO_6_LD-T1     ZENO_6_N001
# 10776      AS_NP26     LOAD     ZENO_6_LD-T2     ZENO_6_N002
# 10777      AS_NP15     LOAD     ZENO_6_LD-T2     ZENO_6_N002
# 10778      AS_NP15      GEN      ZOND_6_UNIT     ZONDWD_6_B1
# 10779      AS_NP26      GEN      ZOND_6_UNIT     ZONDWD_6_B1
#
#                          BUS_ID  FNMVERSION         RELEASE_DATE  GROUP
# 0      35009_0096_WD _21.6_GUWD  22M7_DB114  2022-07-28T00:00:00      1
# 1      35009_0096_WD _21.6_GUWD  22M7_DB114  2022-07-28T00:00:00      1
# 2       35009_0096_WD _21.6_LD1  22M7_DB114  2022-07-28T00:00:00      2
# 3       35009_0096_WD _21.6_LD1  22M7_DB114  2022-07-28T00:00:00      2
# 4      21673_MIDWY GN_34.5_GUS1  22M7_DB114  2022-07-28T00:00:00      3
# ...                         ...         ...                  ...    ...
# 10775   36891_Zeno    _60.0_LD1  22M7_DB114  2022-07-28T00:00:00   5375
# 10776   36891_Zeno    _60.0_LD2  22M7_DB114  2022-07-28T00:00:00   5376
# 10777   36891_Zeno    _60.0_LD2  22M7_DB114  2022-07-28T00:00:00   5376
# 10778   35204_ZONDWD  _60.0_GU1  22M7_DB114  2022-07-28T00:00:00   5377
# 10779   35204_ZONDWD  _60.0_GU1  22M7_DB114  2022-07-28T00:00:00   5377
#
# [10780 rows x 8 columns]

# %%
nodes_arr = Node.to_numpy()
cec_arr = CEC.to_numpy()
new_nodes = np.zeros((nodes_arr.shape[0],nodes_arr.shape[1]+1),dtype=object)
print(new_nodes.shape)

for i in range(nodes_arr.shape[0]):
    for cec in cec_arr:
        if(cec[3]==nodes_arr[i][2]):
            new_nodes[i][:-1] = nodes_arr[i]
            new_nodes[i][-1] = cec[0]

    if new_nodes[i][-1]==0: 
        new_nodes[i][:-1] = nodes_arr[i]
        new_nodes[i][-1] = 'NaN'
    
#     print(new_nodes[i])

# print(new_nodes)
# Out:
# (10780, 9)

# %%
plant = np.zeros((CEC.shape[0],new_nodes.shape[1]),dtype=object)
i = 0;
for node in new_nodes:
    if(node[-1]!='NaN'):
#         print(node)
        plant[i] = node;
        i += 1
    
# pd.DataFrame(new_nodes)

# %%
# Crop off
plant = plant[:i]

# %%
# Map x,y
complete = np.zeros((nodes_arr.shape[0],new_nodes.shape[1]+2),dtype=object)
i = 0
for i in range(plant.shape[0]):
    for a in PowerPlant.to_numpy():
        if(a[3]==plant[-1]):
#             print(p)
#             print(complete[i][:-1].shape)
            complete[i][:-3] = plant[i]
            complete[i][-2] = a[0]
            complete[i][-1] = a[1]
    
    if complete[i][-1]==0: 
        complete[i][:-3] = plant[i]
        complete[i][-2] = 'NaN'
        complete[i][-1] = a[1]

print(complete)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/1n/787vmy157kq5kpk7w7n5wwxh0000gn/T/ipykernel_71714/1424781131.py in <module>
#      12
#      13     if complete[i][-1]==0:
# ---> 14         new_nodes[i][:-1] = nodes_arr[i]
#      15         new_nodes[i][-1] = 'NaN'
#      16
#
# ValueError: could not broadcast input array from shape (8,) into shape (9,)
