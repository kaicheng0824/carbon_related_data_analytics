# %%
import pandas as pd
import numpy as np

# %%
CAISO = pd.read_csv('./data/20220815_20220815_PRC_RTPD_LMP_RTPD_20220816_10_10_35_v3.csv')
SDGE = pd.read_csv('./data/CAISO_SDGE_Node.csv')

# %%
CAISO[20000:30000]
# Out:
#            INTERVALSTARTTIME_GMT        INTERVALENDTIME_GMT      OPR_DT  \
# 20000  2022-08-15T07:00:00-00:00  2022-08-15T07:15:00-00:00  2022-08-15
# 20001  2022-08-15T07:15:00-00:00  2022-08-15T07:30:00-00:00  2022-08-15
# 20002  2022-08-15T07:30:00-00:00  2022-08-15T07:45:00-00:00  2022-08-15
# 20003  2022-08-15T07:45:00-00:00  2022-08-15T08:00:00-00:00  2022-08-15
# 20004  2022-08-15T07:00:00-00:00  2022-08-15T07:15:00-00:00  2022-08-15
# ...                          ...                        ...         ...
# 29995  2022-08-15T07:45:00-00:00  2022-08-15T08:00:00-00:00  2022-08-15
# 29996  2022-08-15T07:00:00-00:00  2022-08-15T07:15:00-00:00  2022-08-15
# 29997  2022-08-15T07:15:00-00:00  2022-08-15T07:30:00-00:00  2022-08-15
# 29998  2022-08-15T07:30:00-00:00  2022-08-15T07:45:00-00:00  2022-08-15
# 29999  2022-08-15T07:45:00-00:00  2022-08-15T08:00:00-00:00  2022-08-15
#
#        OPR_HR             NODE_ID_XML                 NODE_ID  \
# ...

# %%
col_labels = {'PNODE_ID':'NODE_ID'}
SDGE.rename(columns= col_labels, inplace=True)

# %%
SDGE
# Out:
#        AS_ID RES_TYPE          RES_ID          NODE_ID  \
# 0    AS_SP26      GEN   SYDRO_6_FCELL  SANYSDRO_6_N013
# 1    AS_SP15      GEN   SYDRO_6_FCELL  SANYSDRO_6_N013
# 2    AS_SP15     LOAD    SYDRO_6_LD32  SANYSDRO_6_N004
# 3    AS_SP26     LOAD    SYDRO_6_LD32  SANYSDRO_6_N004
# 4    AS_SP26     LOAD    SYDRO_6_LD31  SANYSDRO_6_N001
# ..       ...      ...             ...              ...
# 511  AS_SP26     LOAD   SNTABL_6_LD30  SANTYSBL_6_N001
# 512  AS_SP26     LOAD    WRNERS_6_LD1   WARNERS_6_N001
# 513  AS_SP15     LOAD    WRNERS_6_LD1   WARNERS_6_N001
# 514  AS_SP26      GEN  BREGGO_6_SOLAR   BORREGO_6_N009
# 515  AS_SP15      GEN  BREGGO_6_SOLAR   BORREGO_6_N009
#
#                        BUS_ID  FNMVERSION        RELEASE_DATE  GROUP  \
# 0    22740_SANYSDRO_69.0_GUM1  22M7_DB114  2022-07-28 0:00:00   4836
# 1    22740_SANYSDRO_69.0_GUM1  22M7_DB114  2022-07-28 0:00:00   4836
# 2    22740_SANYSDRO_69.0_LD32  22M7_DB114  2022-07-28 0:00:00   4838
# ...

# %%
SDGE_LMP = pd.merge(CAISO, SDGE, on=['NODE_ID'])

# %%
SANYSIDRO = pd.read_csv('./data/SDGE_NODE_LMP/20220815_20220817_PRC_RTPD_LMP_RTPD_20220816_10_18_12_v3.csv')

# %%
SANYSIDRO
# Out:
#          INTERVALSTARTTIME_GMT        INTERVALENDTIME_GMT      OPR_DT  OPR_HR  \
# 0    2022-08-16T06:00:00-00:00  2022-08-16T06:15:00-00:00  2022-08-15      24
# 1    2022-08-16T06:15:00-00:00  2022-08-16T06:30:00-00:00  2022-08-15      24
# 2    2022-08-16T06:30:00-00:00  2022-08-16T06:45:00-00:00  2022-08-15      24
# 3    2022-08-16T06:45:00-00:00  2022-08-16T07:00:00-00:00  2022-08-15      24
# 4    2022-08-16T06:00:00-00:00  2022-08-16T06:15:00-00:00  2022-08-15      24
# ..                         ...                        ...         ...     ...
# 700  2022-08-16T12:45:00-00:00  2022-08-16T13:00:00-00:00  2022-08-16       6
# 701  2022-08-16T13:45:00-00:00  2022-08-16T14:00:00-00:00  2022-08-16       7
# 702  2022-08-16T14:45:00-00:00  2022-08-16T15:00:00-00:00  2022-08-16       8
# 703  2022-08-16T15:45:00-00:00  2022-08-16T16:00:00-00:00  2022-08-16       9
# 704  2022-08-16T16:45:00-00:00  2022-08-16T17:00:00-00:00  2022-08-16      10
#
# ...
