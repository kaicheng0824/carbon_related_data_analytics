# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../data/NODE_graph.csv",index_col=0)

# %%
df
# Out:
#                  ALPINE_6_N001  ALPINE_6_N005  ARTESN_6_N001  ASH_6_N001  \
# PNODE_ID
# ALPINE_6_N001              1.0            NaN            NaN         NaN
# ALPINE_6_N005              NaN            NaN            NaN         NaN
# ARTESN_6_N001              NaN            NaN            NaN         NaN
# ASH_6_N001                 NaN            NaN            NaN         NaN
# ASH_6_N005                 NaN            NaN            NaN         NaN
# ...                        ...            ...            ...         ...
# VLYCGEN_7_N002             NaN            NaN            NaN         NaN
# VLYCGEN_7_N003             NaN            NaN            NaN         NaN
# WARENCYN_6_N001            NaN            NaN            NaN         NaN
# WARENCYN_6_N002            NaN            NaN            NaN         NaN
# WARNERS_6_N001             NaN            NaN            NaN         NaN
#
#                  ASH_6_N005  ASH_6_N101  AVOCADO_6_N001  AVOCADO_6_N002  \
# ...

# %%
def add_connection(df,Node1,Node2,volt):
    df.loc[(Node1,Node2)] = volt
    df.loc[(Node2,Node1)] = volt
    return df

def del_connection(df,Node1,Node2):
    df.loc[(Node1,Node2)] = 0
    df.loc[(Node2,Node1)] = 0
    return df

# %%
df = add_connection(df,'ALPINE_6_N001','ARTESN_6_N001',100)

# %%
df
# Out:
#                  ALPINE_6_N001  ALPINE_6_N005  ARTESN_6_N001  ASH_6_N001  \
# PNODE_ID
# ALPINE_6_N001            100.0            NaN          100.0         NaN
# ALPINE_6_N005              NaN            NaN            NaN         NaN
# ARTESN_6_N001              NaN            NaN            NaN         NaN
# ASH_6_N001                 NaN            NaN            NaN         NaN
# ASH_6_N005                 NaN            NaN            NaN         NaN
# ...                        ...            ...            ...         ...
# VLYCGEN_7_N002             NaN            NaN            NaN         NaN
# VLYCGEN_7_N003             NaN            NaN            NaN         NaN
# WARENCYN_6_N001            NaN            NaN            NaN         NaN
# WARENCYN_6_N002            NaN            NaN            NaN         NaN
# WARNERS_6_N001             NaN            NaN            NaN         NaN
#
#                  ASH_6_N005  ASH_6_N101  AVOCADO_6_N001  AVOCADO_6_N002  \
# ...
