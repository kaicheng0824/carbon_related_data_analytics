# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
date = '0901_0905'
mcc = pd.read_csv('./SDGE_Node_MCC_TS_T_{}.csv'.format(date))
lmp = pd.read_csv('./SDGE_Node_LMP_TS_T_{}.csv'.format(date))

lmp_bins = np.arange(50,1000,1).tolist()
mcc_bins = np.arange(-1000,1000,0.5).tolist()

def preprocessing(the_lmp,bins,idx):
    N = the_lmp.shape[0]
    print('lmp entries: {}'.format(N))
    time = the_lmp.iloc[idx].to_numpy()[0]
    np_lmp = the_lmp.iloc[idx].to_numpy()[1:].tolist()
    np_lmp = np.asarray(np_lmp,dtype=float)

    
    plt.hist(np_lmp, bins = bins) 
    plt.title("{}".format(time)) 
    plt.show()
    return np_lmp,N

np_lmp,n_lmp = preprocessing(lmp,lmp_bins,500)
np_mcc,n_mcc = preprocessing(mcc,mcc_bins,500)
# Out:
# lmp entries: 385
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/1n/787vmy157kq5kpk7w7n5wwxh0000gn/T/ipykernel_9048/844378281.py in <module>
#      19     return np_lmp,N
#      20
# ---> 21 np_lmp,n_lmp = preprocessing(lmp,lmp_bins,500)
#      22 np_mcc,n_mcc = preprocessing(mcc,mcc_bins,500)
#
# /var/folders/1n/787vmy157kq5kpk7w7n5wwxh0000gn/T/ipykernel_9048/844378281.py in preprocessing(the_lmp, bins, idx)
#       9     N = the_lmp.shape[0]
#      10     print('lmp entries: {}'.format(N))
# ---> 11     time = the_lmp.iloc[idx].to_numpy()[0]
#      12     np_lmp = the_lmp.iloc[idx].to_numpy()[1:].tolist()
#      13     np_lmp = np.asarray(np_lmp,dtype=float)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
mcc = mcc.sort_values(by=['Unnamed: 0']).iloc[:-1]
mcc
# Out:
#                     Unnamed: 0 SANYSDRO_6_N004 NOISLMTR_6_N101 MISSION_6_N001  \
# 1    2022-09-01T07:00:00-00:00        98.35911        98.60331        99.3359
# 25   2022-09-01T07:15:00-00:00         8.86856         8.86856        8.86856
# 49   2022-09-01T07:30:00-00:00        14.43587        14.43587       14.47242
# 73   2022-09-01T07:45:00-00:00        16.49623        16.49623       16.54152
# 2    2022-09-01T08:00:00-00:00         2.99366         2.99366        3.00187
# ..                         ...             ...             ...            ...
# 383  2022-09-05T05:45:00-00:00        16.65836        17.28979       17.28979
# 312  2022-09-05T06:00:00-00:00         23.2094         23.2094       23.27791
# 336  2022-09-05T06:15:00-00:00        21.62467        21.62467       21.62467
# 360  2022-09-05T06:30:00-00:00        11.81338        11.81338       11.83483
# 384  2022-09-05T06:45:00-00:00         9.21922         9.21922        9.21922
#
#     EASTGATE_6_N101  F_6_N001 BATIQTOS_1_N015 PARADISX_6_N004 GENESEE_6_N015  \
# 1         101.12525   99.3359        96.31991        98.60331      101.20323
# 25          8.86856   8.86856         8.91358         8.86856        8.86856
# 49         14.47242  14.47242        14.58525        14.43587       14.47242
# 73         16.54152  16.54152        16.62484        16.49623       16.54152
# 2           3.00943   3.00187         3.01699         2.99366        3.00943
# ..              ...       ...             ...             ...            ...
# 383        17.32676  17.28979        18.03213        16.65836       17.32676
# 312        23.34641  23.27791        24.16456        22.45975       23.34641
# 336        21.69091  21.62467        22.50931        20.93875       21.69091
# 360        11.85628  11.83483        12.78012        11.81338       12.30748
# 384         9.65209   9.21922        10.08637         9.21922        9.65209
#
#     PALOMAR_1_N001  ... BERNARDO_6_N013 BDLRKSP2_7_B1 DELMAR_6_N011  \
# 1         95.83151  ...        10.08637        9.6535       9.21922
# 25         8.91358  ...        -2.43828      -2.81605      -2.43828
# 49        14.58525  ...         4.89259       4.46714       4.67986
# 73        16.62484  ...        10.75982       9.82419        10.292
# 2          3.01699  ...       101.93582      98.35911     101.20323
# ..             ...  ...             ...           ...           ...
# 383       18.03213  ...        26.64514    -265.65054      26.64514
# 312       24.16456  ...        25.10094      24.28358      25.10094
# 336       23.19523  ...        26.22296       25.3582       26.1008
# 360       12.78012  ...        22.62144      21.88005      22.62144
# 384       10.08637  ...        17.99516      16.65836      17.32676
#
#     MONSRATE_6_N007 GRANITE_6_N007 MISSION_6_N049 IMPRLBCH_6_N004  \
# 1           9.65209       10.51923        9.21922         9.21922
# 25         -2.01865       -2.81605       -2.43828        -2.81605
# 49          5.10531        4.46714        4.67986         4.46714
# 73         11.22764        9.82419         10.292         9.82419
# 2          90.69704        99.8243        99.3359        98.35911
# ..              ...            ...            ...             ...
# 383        28.08732       26.00022       26.49279        58.27624
# 312        26.61541       24.28358       24.98069        24.28358
# 336        27.83033        25.3582        26.1008         25.3582
# 360        24.18527       21.88005       22.54037        21.88005
# 384        18.70053       17.28979       17.28979        16.65836
#
#     RINCON_1_N003 RCARMEL_6_N001 BDLRKSP1_7_B1
# 1         9.21922       21.72068       9.65209
# 25            0.0       -2.43828      -2.81605
# 49            0.0        4.67986       4.46714
# 73            0.0         10.292       9.82419
# 2       -14.53822      102.83464      98.35911
# ..            ...            ...           ...
# 383      35.64923       26.64514    -265.65054
# 312      28.25851       25.10094      24.28358
# 336      28.70867       26.22296       25.3582
# 360      19.04942       22.62144      21.88005
# 384      36.54322       17.32676      16.65836
#
# [384 rows x 258 columns]

# %%
lmp = lmp.sort_values(by=['Unnamed: 0']).iloc[:-1]
lmp
# Out:
#                     Unnamed: 0 SANYSDRO_6_N004 NOISLMTR_6_N101 MISSION_6_N001  \
# 1    2022-09-01T07:00:00-00:00       208.60815       208.31033       208.3133
# 25   2022-09-01T07:15:00-00:00          134.42          134.42         134.42
# 2        80.23198       211.8016     208.96255
# ..            ...            ...           ...
# 383     146.12675      146.72656    -151.30962
# 312     167.83533      177.89705     170.45622
# 336     169.97836       182.1218     173.01407
# 360     142.66962      160.09956      153.3572
# 384      132.0997      123.86203     118.34808
#
# [384 rows x 258 columns]

# %%
import matplotlib.animation as animation

# %%
def prepare_animation(bar_container):
    def animate(frame_number):
        # simulate new data coming in
        time = lmp.iloc[frame_number].to_numpy()[0]
        np_lmp = lmp.iloc[frame_number].to_numpy()[1:].tolist()
        np_lmp = np.asarray(np_lmp,dtype=float)

        ax.set_title('Date: {}'.format(time))
        ax.set_xlabel("Price")
        ax.set_ylabel("Count")

        n, _ = np.histogram(np_lmp, lmp_bins)
        for count, rect in zip(n, bar_container.patches):
            rect.set_height(count)
        return bar_container.patches
    return animate

# def generateVideo(np_lmp,name,bins,N):    
    # histogram our data with numpy
name = 'LMP'
n, _ = np.histogram(np_lmp, lmp_bins)

fig, ax = plt.subplots()
_, _, bar_container = ax.hist(np_lmp, lmp_bins, lw=1,
                              ec="yellow", fc="green", alpha=0.5)
ax.set_ylim(top=170)  # set safe limit to ensure that all data is visible.

ani = animation.FuncAnimation(fig, prepare_animation(bar_container), n_lmp-1,
                              repeat=True, blit=False)

writervideo = animation.FFMpegWriter(fps=5)
ani.save('./{}_TS_Histogram_{}.mp4'.format(name,date), writer=writervideo)
plt.close()
#     print('DONE')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/1n/787vmy157kq5kpk7w7n5wwxh0000gn/T/ipykernel_9048/1166868337.py in <module>
#      30
#      31 writervideo = animation.FFMpegWriter(fps=5)
# ---> 32 ani.save('./{}_TS_Histogram_{}.mp4'.format(name,date), writer=writervideo)
#      33 plt.close()
#      34 #     print('DONE')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1171                 for anim, d in zip(all_anim, data):
#    1172                     # TODO: See if turning off blit is really necessary
# -> 1173                     anim._draw_next_frame(d, blit=False)
#    1174                     if progress_callback is not None:
#    1175                         progress_callback(frame_number, total_frames)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1206         # post- draw, as well as the drawing of the frame itself.
#    1207         self._pre_draw(framedata, blit)
# -> 1208         self._draw_frame(framedata)
#    1209         self._post_draw(framedata, blit)
#    1210
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1774         # Call the func with framedata and args. If blitting is desired,
#    1775         # func needs to return a sequence of any artists that were modified.
# -> 1776         self._drawn_artists = self._func(framedata, *self._args)
#    1777
#    1778         if self._blit:
#
# /var/folders/1n/787vmy157kq5kpk7w7n5wwxh0000gn/T/ipykernel_9048/1166868337.py in animate(frame_number)
#       2     def animate(frame_number):
#       3         # simulate new data coming in
# ----> 4         time = lmp.iloc[frame_number].to_numpy()[0]
#       5         np_lmp = lmp.iloc[frame_number].to_numpy()[1:].tolist()
#       6         np_lmp = np.asarray(np_lmp,dtype=float)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
def prepare_animation(bar_container):
    def animate(frame_number):
        # simulate new data coming in
        time = mcc.iloc[frame_number].to_numpy()[0]
        np_mcc = mcc.iloc[frame_number].to_numpy()[1:].tolist()
        np_mcc = np.asarray(np_mcc,dtype=float)

        ax.set_title('Date: {}'.format(time))
        ax.set_xlabel("Price")
        ax.set_ylabel("Count")


        n, _ = np.histogram(np_mcc, mcc_bins)
        for count, rect in zip(n, bar_container.patches):
            rect.set_height(count)
        return bar_container.patches
    return animate

# def generateVideo(np_lmp,name,bins,N):    
    # histogram our data with numpy
name = 'MCC'
n, _ = np.histogram(np_mcc, mcc_bins)

fig, ax = plt.subplots()
_, _, bar_container = ax.hist(np_mcc, mcc_bins, lw=1,
                              ec="yellow", fc="green", alpha=0.5)
ax.set_ylim(top=257)  # set safe limit to ensure that all data is visible.

ani = animation.FuncAnimation(fig, prepare_animation(bar_container), n_mcc-1,
                              repeat=True, blit=False)

writervideo = animation.FFMpegWriter(fps=5)
ani.save('./{}_TS_Histogram_{}.mp4'.format(name,date), writer=writervideo)
plt.close()
#     print('DONE')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/1n/787vmy157kq5kpk7w7n5wwxh0000gn/T/ipykernel_9048/1236638368.py in <module>
#      31
#      32 writervideo = animation.FFMpegWriter(fps=5)
# ---> 33 ani.save('./{}_TS_Histogram_{}.mp4'.format(name,date), writer=writervideo)
#      34 plt.close()
#      35 #     print('DONE')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1171                 for anim, d in zip(all_anim, data):
#    1172                     # TODO: See if turning off blit is really necessary
# -> 1173                     anim._draw_next_frame(d, blit=False)
#    1174                     if progress_callback is not None:
#    1175                         progress_callback(frame_number, total_frames)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1206         # post- draw, as well as the drawing of the frame itself.
#    1207         self._pre_draw(framedata, blit)
# -> 1208         self._draw_frame(framedata)
#    1209         self._post_draw(framedata, blit)
#    1210
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1774         # Call the func with framedata and args. If blitting is desired,
#    1775         # func needs to return a sequence of any artists that were modified.
# -> 1776         self._drawn_artists = self._func(framedata, *self._args)
#    1777
#    1778         if self._blit:
#
# /var/folders/1n/787vmy157kq5kpk7w7n5wwxh0000gn/T/ipykernel_9048/1236638368.py in animate(frame_number)
#       2     def animate(frame_number):
#       3         # simulate new data coming in
# ----> 4         time = mcc.iloc[frame_number].to_numpy()[0]
#       5         np_mcc = mcc.iloc[frame_number].to_numpy()[1:].tolist()
#       6         np_mcc = np.asarray(np_mcc,dtype=float)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds
