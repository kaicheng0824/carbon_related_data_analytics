# %%
import numpy as np
import pandas as pd

# %%
date = '0901_0905'
df1 = pd.read_csv('../.././data/SDGE_NODE_LMP/20220901_20220905_PRC_RTPD_LMP_RTPD_20220924_18_55_55_v3.csv')
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/1n/787vmy157kq5kpk7w7n5wwxh0000gn/T/ipykernel_9060/4243310599.py in <module>
#       1 date = '0901_0905'
# ----> 2 df1 = pd.read_csv('../.././data/SDGE_NODE_LMP/20220816_20220823_PRC_RTPD_LMP_RTPD_20220924_10_09_46_v3.csv')
#       3 df1
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../.././data/SDGE_NODE_LMP/20220816_20220823_PRC_RTPD_LMP_RTPD_20220924_10_09_46_v3.csv'

# %%
import sys
import time

def restart_line():
    sys.stdout.flush()
    time.sleep(0.05)
    sys.stdout.write('\r')
    sys.stdout.flush()

# %%
index = 0
N = 257 # Total file
import os
for root, dirs, files in os.walk(r'/Users/kaiwencheng/Desktop/research/SRIP/carbon_related_data_analytics/power_plant_related/data/SDGE_NODE_LMP'):
    for filename in files:
        if(filename[-4:]!='.csv'):
            continue
        
        sys.stdout.write('Concatinating {}/{}'.format(index,N))
        restart_line()

        index += 1
        df2 = pd.read_csv('../.././data/SDGE_NODE_LMP/{}'.format(filename))
        df1 = pd.concat([df1,df2],ignore_index=True)
# Out:
# Concatinating 257/257
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/1n/787vmy157kq5kpk7w7n5wwxh0000gn/T/ipykernel_9060/1453696019.py in <module>
#      11
#      12         index += 1
# ---> 13         df2 = pd.read_csv('../.././data/SDGE_NODE_LMP/{}'.format(filename))
#      14         df1 = pd.concat([df1,df2],ignore_index=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../.././data/SDGE_NODE_LMP/20220816_20220823_PRC_RTPD_LMP_RTPD_20220829_13_36_33_v3.csv'

# %%
# df1['NODE_ID'].drop_duplicates().shape
Node = df1

# %%
# Get LMP Online
LMP = Node[Node['LMP_TYPE']=='LMP'] 
MCC = Node[Node['LMP_TYPE']=='MCC'] # Congestion
MCE = Node[Node['LMP_TYPE']=='MCE'] # Energy
MCL = Node[Node['LMP_TYPE']=='MCL'] # Loss

# %%
LMP.iloc[672:700]
# Out:
#           INTERVALSTARTTIME_GMT        INTERVALENDTIME_GMT      OPR_DT  \
# 3360  2022-08-16T07:00:00-00:00  2022-08-16T07:15:00-00:00  2022-08-16
# 3361  2022-08-16T08:00:00-00:00  2022-08-16T08:15:00-00:00  2022-08-16
# 3362  2022-08-16T09:00:00-00:00  2022-08-16T09:15:00-00:00  2022-08-16
# 3363  2022-08-16T10:00:00-00:00  2022-08-16T10:15:00-00:00  2022-08-16
# 3364  2022-08-16T11:00:00-00:00  2022-08-16T11:15:00-00:00  2022-08-16
# 3365  2022-08-16T12:00:00-00:00  2022-08-16T12:15:00-00:00  2022-08-16
# 3366  2022-08-16T13:00:00-00:00  2022-08-16T13:15:00-00:00  2022-08-16
# 3367  2022-08-16T14:00:00-00:00  2022-08-16T14:15:00-00:00  2022-08-16
# 3368  2022-08-16T15:00:00-00:00  2022-08-16T15:15:00-00:00  2022-08-16
# 3369  2022-08-16T16:00:00-00:00  2022-08-16T16:15:00-00:00  2022-08-16
# 3370  2022-08-16T17:00:00-00:00  2022-08-16T17:15:00-00:00  2022-08-16
# 3375      16  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3376      17  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3377      18  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3378      19  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3379      20  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3380      21  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3381      22  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3382      23  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3383      24  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3384       1  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3385       2  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3386       3  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
# 3387       4  POINTLMA_6_N013  POINTLMA_6_N013  POINTLMA_6_N013          RTPD
#
#      LMP_TYPE XML_DATA_ITEM    PNODE_RESMRID GRP_TYPE  POS        PRC  \
# 3360      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   87.58975
# 3361      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   91.61941
# 3362      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   85.61753
# 3363      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   85.57118
# 3364      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   83.56780
# 3365      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   85.34542
# 3366      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   94.04516
# 3367      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   93.81008
# 3368      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   73.87755
# 3369      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   71.67396
# 3370      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   78.38085
# 3371      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   79.99862
# 3372      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   85.91400
# 3373      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   90.11123
# 3374      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1  109.75310
# 3375      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1  114.36265
# 3376      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1  137.99033
# 3377      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1  164.01297
# 3378      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1  341.39200
# 3379      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1  647.67535
# 3380      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1  336.34440
# 3381      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1  197.10141
# 3382      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1  167.47913
# 3383      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1  134.01646
# 3384      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   82.00823
# 3385      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   87.98877
# 3386      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   85.18890
# 3387      LMP       LMP_PRC  POINTLMA_6_N013      ALL    1   85.04274
#
#       OPR_INTERVAL  GROUP
# 3360             1      1
# 3361             1      1
# 3362             1      1
# 3363             1      1
# 3364             1      1
# 3365             1      1
# 3366             1      1
# 3367             1      1
# 3368             1      1
# 3369             1      1
# 3370             1      1
# 3371             1      1
# 3372             1      1
# 3373             1      1
# 3374             1      1
# 3375             1      1
# 3376             1      1
# 3377             1      1
# 3378             1      1
# 3379             1      1
# 3380             1      1
# 3381             1      1
# 3382             1      1
# 3383             1      1
# 3384             2      1
# 3385             2      1
# 3386             2      1
# 3387             2      1

# %%
def generateTS(LMP):
    Node_ID = LMP['NODE_ID'].drop_duplicates().to_numpy()
    time = LMP['INTERVALSTARTTIME_GMT'].drop_duplicates().to_numpy()
    Node_ID.dtype = object
    time.dtype = object

    N_node = Node_ID.shape[0]
    N_timeStep = time.shape[0]
    total_N = LMP.shape[0]
    
    LMP_matrix = np.zeros((N_node,N_timeStep+1),dtype=object)

    total_N = N_node*N_timeStep
    PRC_col = -3
    node_col = -10
    
    print('Number of Node: {}'.format(N_node))
    print('Number of timestep: {}'.format(N_timeStep))
    print('Total Entries: {}'.format(total_N))
    print('Entries / Timestep = {}'.format(int(total_N/N_timeStep)))
    print('--------------------------------')

    for i in range(total_N):
        LMP_matrix[int(i/N_timeStep)][int(i%N_timeStep)+1] = LMP.iloc[i][PRC_col] # Plus one to make space for PNODE index

    for i in range(N_node):
        LMP_matrix[i][0] = Node_ID[i]
        
    time = np.insert(time,0,'PNODE_ID')
    pd_LMP = pd.DataFrame(LMP_matrix,columns=time,index=Node_ID)
    pd_LMP_Trans = pd_LMP.T
    
    return pd_LMP,pd_LMP_Trans

# %%
pd_MCC,pd_MCC_Trans = generateTS(MCC)
pd_LMP,pd_LMP_Trans = generateTS(LMP)
pd_MCE,pd_MCE_trans = generateTS(MCE)
# Out:
# Number of Node: 257
# Number of timestep: 672
# Total Entries: 172704
# Entries / Timestep = 257
# --------------------------------
# Number of Node: 257
# Number of timestep: 672
# Total Entries: 172704
# Entries / Timestep = 257
# --------------------------------
# Number of Node: 257
# Number of timestep: 672
# Total Entries: 172704
# Entries / Timestep = 257
# --------------------------------

# %%
import matplotlib.pyplot as plt
a= pd_MCE.iloc[1].to_numpy()[1:]
# print()
plt.plot(a)

# %%
# Add LMP with Lat,Long
node_loc = pd.read_csv('../../data/Node_data/CAISO_SDGE_Node.csv')

def addLatLng(pd_MCC,node_loc):
    pd_MCC = pd_MCC.set_index('PNODE_ID').join(node_loc.set_index('PNODE_ID'))
    return pd_MCC

# %%
pd_MCC = addLatLng(pd_MCC,node_loc)
pd_LMP = addLatLng(pd_LMP,node_loc)
# WARNERS_6_N001                   73.87755                  64.91031  ...
# WARNERS_6_N001                   73.87755                  64.91031  ...
#
#                    AS_ID RES_TYPE         RES_ID                    BUS_ID  \
# PNODE_ID
# ALPINE_6_N001    AS_SP26     LOAD  ALPINE_6_LD32   22004_ALPINE _69.0_LD32
# ALPINE_6_N001    AS_SP15     LOAD  ALPINE_6_LD32   22004_ALPINE _69.0_LD32
# ALPINE_6_N005    AS_SP26     LOAD  ALPINE_6_LD30   22004_ALPINE _69.0_LD30
# ALPINE_6_N005    AS_SP15     LOAD  ALPINE_6_LD30   22004_ALPINE _69.0_LD30
# ARTESN_6_N001    AS_SP26     LOAD  ARTESN_6_LD32   22009_ARTESN _69.0_LD32
# ...                  ...      ...            ...                       ...
# WARENCYN_6_N001  AS_SP15     LOAD  WRNCYN_6_LD30  22880_WARENCYN_69.0_LD30
# WARENCYN_6_N002  AS_SP26     LOAD  WRNCYN_6_LD20  22880_WARENCYN_69.0_LD20
# WARENCYN_6_N002  AS_SP15     LOAD  WRNCYN_6_LD20  22880_WARENCYN_69.0_LD20
# WARNERS_6_N001   AS_SP26     LOAD   WRNERS_6_LD1   22884_WARNERS _69.0_LD1
# WARNERS_6_N001   AS_SP15     LOAD   WRNERS_6_LD1   22884_WARNERS _69.0_LD1
#
#                  FNMVERSION        RELEASE_DATE GROUP        Lat        Long  \
# PNODE_ID
# ALPINE_6_N001    22M7_DB114  2022-07-28 0:00:00    65  32.827798 -116.789691
# ALPINE_6_N001    22M7_DB114  2022-07-28 0:00:00    65  32.827798 -116.789691
# ALPINE_6_N005    22M7_DB114  2022-07-28 0:00:00    64  32.827753 -116.790115
# ALPINE_6_N005    22M7_DB114  2022-07-28 0:00:00    64  32.827753 -116.790115
# ARTESN_6_N001    22M7_DB114  2022-07-28 0:00:00   135  33.021228 -117.134101
# ...                     ...                 ...   ...        ...         ...
# WARENCYN_6_N001  22M7_DB114  2022-07-28 0:00:00  5339  33.015456 -117.002003
# WARENCYN_6_N002  22M7_DB114  2022-07-28 0:00:00  5338  33.015456 -117.002358
# WARENCYN_6_N002  22M7_DB114  2022-07-28 0:00:00  5338  33.015456 -117.002358
# WARNERS_6_N001   22M7_DB114  2022-07-28 0:00:00  5340  33.247363 -116.675766
# WARNERS_6_N001   22M7_DB114  2022-07-28 0:00:00  5340  33.247363 -116.675766
#
#                 Unnamed: 10
# PNODE_ID
# ALPINE_6_N001           NaN
# ALPINE_6_N001           NaN
# ALPINE_6_N005           NaN
# ALPINE_6_N005           NaN
# ARTESN_6_N001           NaN
# ...                     ...
# WARENCYN_6_N001         NaN
# WARENCYN_6_N002         NaN
# WARENCYN_6_N002         NaN
# WARNERS_6_N001          NaN
# WARNERS_6_N001          NaN
#
# [516 rows x 682 columns]

# %%
pd_LMP.to_csv('./SDGE_Node_LMP_TS_{}.csv'.format(date))
pd_MCC.to_csv('./SDGE_Node_MCC_TS_{}.csv'.format(date))

pd_LMP_Trans.to_csv('./SDGE_Node_LMP_TS_T_{}.csv'.format(date))
pd_MCC_Trans.to_csv('./SDGE_Node_MCC_TS_T_{}.csv'.format(date))
